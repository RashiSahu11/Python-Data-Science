# %% [markdown]
# DICTIONARY

# %% [markdown]
#  - different ways to create a dictionary
#  - access key value pairs
#  - adding a new pair
#  - deleting a pair
#  - updating a pair
#  - loops in dictionary
#  - nested dictionary
#  - access value in nested dictionary

# %%
student={'name':'rashi',
         'age':19,
        'subject':'python'
}        
print(student)
# Out:
# {'name': 'rashi', 'age': 19, 'subject': 'python'}

# %%
temp={'banglore':[26,28,24],
      'chennai':[28,27,31],
      'uttrakhand':[28,24,26]
      }
print(temp)
# Out:
# {'banglore': [26, 28, 24], 'chennai': [28, 27, 31], 'uttrakhand': [28, 24, 26]}

# %%
info = dict(name = 'joy', course='bca', age=20)
print(info)
# Out:
# {'name': 'joy', 'course': 'bca', 'age': 20}

# %%
#accessing values using key
#1st method
student['name']
student['age']
# Out:
# 19

# %%
#2nd method
student.get('name')# get method
# Out:
# 'rashi'

# %%
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name', 'age', 'subject'])
# dict_values(['rashi', 19, 'python'])
# dict_items([('name', 'rashi'), ('age', 19), ('subject', 'python')])

# %%
#adding a new pair
student['city']='Edinburgh'
print(student)
# Out:
# {'name': 'rashi', 'age': 19, 'subject': 'python', 'city': 'Edinburgh'}

# %%
#deleting a pair
del student['city']
print(student)
# Out:
# {'name': 'rashi', 'age': 19, 'subject': 'python'}

# %%
#update
student['subject']='data science'
print(student)
# Out:
# {'name': 'rashi', 'age': 19, 'subject': 'data science'}

# %%
#loops in dict
for i,v in student.items():
    print(f'{i}${v}')
# Out:
# name$rashi
# age$19
# subject$data science

# %%
a=10
b=20
print('sumis :',a+b)
print("sum of",a,'and',b,'is',a+b)
print(f'sum of {a} and {b} is {a+b}')#f string to format
# Out:
# sumis : 30
# sum of 10 and 20 is 30
# sum of 10 and 20 is 30

# %%
#nested dictionary
company={
    'empoo1':{'name':'Rahul',
            'salary':50000,
            'department':'datascience'
    },
    'emp002':{'name':'raj',
              'salary':40000,
              'department':'powerbi'
    }
}
print(company)
# Out:
# {'empoo1': {'name': 'Rahul', 'salary': 50000, 'department': 'datascience'}, 'emp002': {'name': 'raj', 'salary': 40000, 'department': 'powerbi'}}

# %%
company['emp003']= {
    'name':'sun',
    'salary':30000,
    'department':'AI'
}
print(company)
# Out:
# {'empoo1': {'name': 'Rahul', 'salary': 50000, 'department': 'datascience'}, 'emp002': {'name': 'raj', 'salary': 40000, 'department': 'powerbi'}, 'emp003': {'name': 'sun', 'salary': 30000, 'department': 'AI'}}

# %%
company['emp002']['name']='raj yadav'
print(company)
# Out:
# {'empoo1': {'name': 'Rahul', 'salary': 50000, 'department': 'datascience'}, 'emp002': {'name': 'raj yadav', 'salary': 40000, 'department': 'powerbi'}, 'emp003': {'name': 'sun', 'salary': 30000, 'department': 'AI'}}

# %%
#calculate the avg tem of banglore (using the dictionary key and values pair)
temp={'banglore':[26,28,24],
      'chennai':[28,27,31],
      'uttrakhand':[28,24,26]
      }
avg=sum(temp['banglore'])/len(temp['banglore'])
print ('Average temperature of banglore is:',avg)
# Out:
# Average temperature of banglore is: 26.0

# %%
student={'name':'rashi',
         'course':'BCA',
         'age':19}
print(student)
# Out:
# {'name': 'rashi', 'course': 'BCA', 'age': 19}

# %%
student['city']='edinburgh'

# %%
print(student)
# Out:
# {'name': 'rashi', 'course': 'BCA', 'age': 19, 'city': 'edinburgh'}

# %%
d1={'a':1}
d2=d1
d1['b']=2
d2['a']=3
print(d1)
# Out:
# {'a': 3, 'b': 2}

# %%
a='hello' 
b='he'+'llo'
print(a is b)
# Out:
# True

# %%
x=[1,2,3]
y=x[:]
x[0]=10
print(y)
print(x)
# Out:
# [1, 2, 3]
# [10, 2, 3]

# %%
abc=[4,5,6]
d=abc[:]
abc[0]=10
print(d)
print(abc)
# Out:
# [4, 5, 6]
# [10, 5, 6]
