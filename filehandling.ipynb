# %%
#write mode
file=open("data.txt",'w')#open file in a write mode
file.write("This is a new line of text.\n")
file.close()

# %%
#read mode
file=open('data.txt','r')
print(file.read())
file.close()
# Out:
# This is a new line of text.

# %%
file=open("data.txt",'w')#open file in a write mode
file.write("helllo worlddd.\n")
file.close()

# %%
file=open("data.txt",'x')
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 file=open("data.txt",'x')
#       2 file.close()
#
# FileExistsError: [Errno 17] File exists: 'data.txt'

# %%
#append mode
file=open('data.txt','a')
file.write("This is appended line")
file.close()

# %%
#file automatically closes WITH
with open("data.txt",'r') as file:
    content=file.read()
    print(content)
# Out:
# helllo worlddd.
# This is appended line

# %%
#read specific number of characters
file=open("data.txt",'r')
print(file.read(10))#read first 10 acharacters
file.close()
# Out:
# helllo wor

# %%
#read one line at a time
file=open("data.txt",'r')
print(file.readline())#reads first line
file.close()
# Out:
# helllo worlddd.

# %%
file=open('data.txt','r')
print(file.name)#name of a file
print(file.mode)#mode in which the file is opened
print(file.closed)#check if the file is closed or not
print(file.read(5))#reads first characters
print(file.tell())#currrent position of file cursor
file.seek(0)#move the file cursor to the beging of the file
# Out:
# data.txt
# r
# False
# helll
# 5
# 0

# %% [markdown]
# EXCEPTION HANDLING

# %%
age=int(input("Enter your age:"))
if age>18:
    print("Valid")
else:
    print("Invalid")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 age=int(input("Enter your age:"))
#       2 if age>18:
#       3     print("Valid")
#       4 else:
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
try:
    age=int(input("Enter your age:"))
    print(age)
except ValueError:  
    print("please enter a valid age")
# Out:
# please enter a valid age

# %%
try:
    file=open('newfile.txt','x')
    print("File created successfully")
except FileExistsError:
    print("File already exists")
finally:    
    file.close()
# Out:
# File already exists

# %%
file=open('student.txt','w')
file.write("hello python\nWelcome to file handling\n")
file.close()

# %%
file=open("student.txt",'r')
print(file.read())
file.close()
# Out:
# hello python
# Welcome to file handling

# %%
file=open('student.txt','a')
file.write("Learning Data analytics\n")
file.close()

# %%
file=open("student.txt",'r')
print(file.readlines())
file.close()
# Out:
# ['hello python\n', 'Welcome to file handling\n', 'Learning Data analytics\n']

# %%
file=open("student.txt",'r')
print(file.readline())
file.close()
# Out:
# hello python

# %%
file=open("sample.txt",'w')
file.write("python\njava\nsql")
file.close()

# %%
file=open("sample.txt",'r')
print(file.readline())
print(file.readline())
print(file.readline())
file.close()
# Out:
# python
#
# java
#
# sql

# %%
with open("student.txt",'r') as file:
    data=file.read()
    print(data)
# Out:
# hello python
# Welcome to file handling
# Learning Data analytics

# %%
with open("student.txt",'a')as file:
    file.write("Hello")
    file.close()

# %%
file=open("marks.txt",'w')
file.write("Rashi 100\nNeha 88\nReem 76")
file.close()

# %%
file=open('marks.txt','r')
print(file.read())
file.close()
# Out:
# Rashi 100
# Neha 88
# Reem 76

# %%
file=open('marks.txt','a')
file.write('\nkendal\n 45')
file.close()
