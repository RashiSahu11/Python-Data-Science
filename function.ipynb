# %% [markdown]
# `FUNCTION`: a block of code to reuse any functionality
#
# `Types of functions`
# - user defined functions
#      - parametrised functions
#      - non parametrised functions
#      - return function
#      - non return function
#      - default parametrised functions
#      - lambda functions
# - built in functions
#      - append, len etc.

# %%
def greet(): #function definition
    print("hello user")
    print("welcome to code world")
    print("have a great day")
greet()    # function calling
print ("see u again")
# Out:
# hello user
# welcome to code world
# have a great day
# see u again

# %%
greet()
# Out:
# hello user
# welcome to code world
# have a great day

# %%
#parametrised
def sum(a,b): #parameters
    print(a+b)
sum(10,20) #argument
# Out:
# 30

# %%
#check no is even or odd
def evod(s):
    if s%2==0:
       print('even') 
    else:
       print('odd')    
evod(3)
# Out:
# odd

# %%
# average of 4 numbers
def avg(a,b,c,d):
    sum=a+b+c+d
    print('average of numbers',sum/4)
avg(1,2,3,1)
# Out:
# average of numbers 1.75

# %%
#non return
def sum(a,b): 
    print(a+b)
result=sum(10,20) 
print(result)
# Out:
# 30
# None

# %%
#return fuction
def sum(a,b):
    return a+b

result=sum(10,20)
print(result)
# Out:
# 30

# %%
#default parametrised function
def country(country='US'):
    print(f'I love {country}')

country('Belgium')
country()
# Out:
# I love Belgium
# I love US

# %%
#take a list of 10 integers and return a new list with the square of all the elements
#take a list of 10 integers and return a new list of all the odd number
lst=[1,3,4,2,6,8,9,0,2,6]
lst2=[]
for i in lst:
    lst2.append(i**2)
print(lst2)
# Out:
# [1, 9, 16, 4, 36, 64, 81, 0, 4, 36]

# %%
lst=[1,3,4,2,6,8,0,2,6]
lst2=[]
for i in lst:
    if i%2!=0:
        lst2.append(i)
print(lst2)
# Out:
# [1, 3]

# %% [markdown]
# LAMBDA FUNCTION

# %% [markdown]
# variable=lambda parameter:expression

# %%
square= lambda x:x**2
print(square(4))
# Out:
# 16

# %%
even = lambda x :'even' if x%2==0 else 'odd'
print(even(7))
# Out:
# odd

# %%
def sum(a,b):
    return a+b
print(sum(10,20))
# Out:
# 30

# %%
def calculate_sum(a,b):
    return a+b
print(calculate_sum(3,5))
# Out:
# 8

# %%
#Write a function called square that takes a number and prints its square.
def squ(num):
    return num**2
print(squ(6))
# Out:
# 36

# %%
def add(a, b):
    return a + b

x = add(4, 6)
print(x)
# Out:
# 10

# %%
#Write a function is_even(num) that returns True if the number is even and False if it is odd.
def check_no(num):
    if num%2==0:
        print("even")
    else:
        print("odd")    

print(check_no(9))
# Out:
# odd
# None

# %%
lst=[1,3,2,5,6,8]
squares = list(map(lambda x:x**2, lst))
print(squares)
# Out:
# [1, 9, 4, 25, 36, 64]

# %%
number=[1,2,3,4,5,6,7,8,9]
even_number=list(filter(lambda x:x%2==0, number))
print(even_number)
# Out:
# [2, 4, 6, 8]

# %%
p = lambda x:'pallindrom' if x == x[::-1] else 'not pallindrom'
print(p('madam'))
# Out:
# pallindrom

# %%
#WAF to check a no. is prime or not
num= lambda x:
x>=1
return False
for i in range(2,num):
    if x
# Out:
#   Cell In[21], line 2
#     num= lambda x:
#                   ^
# SyntaxError: invalid syntax

# %%
reverse= lambda x:x[::-1]
print(reverse(412345))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 reverse= lambda x:x[::-1]
# ----> 2 print(reverse(412345))
#
# Cell In[1], line 1, in <lambda>(x)
# ----> 1 reverse= lambda x:x[::-1]
#
# TypeError: 'int' object is not subscriptable

# %%
char=input('enter the character')
def vowel(char):
    if 'a','e','i','o','u' in char:
        print(len())
# Out:
#   Cell In[13], line 3
#     if 'a','e','i','o','u' in char:
#           ^
# SyntaxError: invalid syntax

# %%
def func():
    print("function called")
    return False

x=True or func()
print("Done")
# Out:
# Done

# %%
a=[]
b=[]
print(a==b,a is b)
# Out:
# True False

# %%
def greet():
    print("Welcome to the python world")

# %%
greet()
# Out:
# Welcome to the python world

# %%
def mul(a,b):
    print(a*b)
mul(2,2)
# Out:
# 4

# %%
mul(5,4)
# Out:
# 20

# %%
def cube(a):
    print(a**3)
cube(3)
# Out:
# 27

# %%
def test():
    return 10
    print("Hello")

print(test())
# Out:
# 10

# %%
def find_max(a,b):
    if a>b:
        return a
    else:
        return b
find_max(10,20)
# Out:
# 20

# %%
def sum_list(a,b,c,d):
    print(a+b+c+d)
sum_list(1,2,3,4)
# Out:
# 10

# %%
def add(a,b=10):
    return a+b
print(add(5))
print (add(5,20))
# Out:
# 15
# 25

# %%
double=lambda x:x*2
print(double(5))
# Out:
# 10

# %%
squ=lambda x:x**2
print(squ(4))
# Out:
# 16

# %%
check_no=lambda x:'even'if x%2==0 else'odd'
print(check_no(4))
# Out:
# even

# %%
number=[1,2,3,4,5]
result=list(map(lambda x:x*2,number))
print(result)
# Out:
# [2, 4, 6, 8, 10]

# %%
number=[1,2,3,4,5,6]
result=list(filter(lambda x:x>3,number))
print(result)
# Out:
# [4, 5, 6]

# %%
sales=[100,250,80,400,150]
result=list(filter(lambda x:x>150,sales))
print(result)
# Out:
# [250, 400]

# %%
prices=[100,200,300]
result=list(map(lambda x:x*0.18+x ,prices))
print(result)
# Out:
# [118.0, 236.0, 354.0]

# %%
data=[10,20,30,40]
result=list(map(lambda x:x+5,
            filter(lambda x:x>20,data)))
print(result)
# Out:
# [35, 45]

# %%
def area_rectangle(l,w):
    return(l*w)
print('AREA OF RECTANGLE',area_rectangle(4,5))
# Out:
# AREA OF RECTANGLE 20

# %%
def largest(a,b):
    return a if a>b  else b
print(largest(1,8))
# Out:
# 8

# %%
def largestt(a,b,c):
    if a>b  and b>c:
        return a
    elif b>a and b>c:
        return b
    else:
        return c
print(largestt(2,4,3))
# Out:
# 4

# %%
def factorial(f):
    for i in range(1,f):
     return i*f
print(factorial(5))
# Out:
# 5

# %%
lst=[1,2,3,4,5,6,7,8,9]
def count_even(lst):
    if lst%2==0:
        print(lst)

# %%
sqr=lambda x:x**2
print(sqr(777))
# Out:
# 603729

# %%
cube=lambda x:x**3
print(cube(111))
# Out:
# 1367631

# %%
def multiply(a,b):
    return(a*b)
print(multiply(47,92))
# Out:
# 4324

# %%
marks=[40,50,60]
result=(list(map(lambda x:x+5,marks)))
print(result)
# Out:
# [45, 55, 65]

# %%
numbers=[10,12,15,17,20]
result=list(filter( lambda x:x%5==0,numbers))
print(result)
# Out:
# [10, 15, 20]

# %%
numbers=[1,2,3]
result=list(map(lambda x:x+10,numbers))
print(result)
# Out:
# [11, 12, 13]

# %%
def largestsnum(a,b,c,d,e):
    return max(a,b,c,d,e)

print(largestsnum(37,58,90,12,43))
# Out:
# 90

# %%
def factorial(n):
    fact=1

    for i in range(1,n+1):
        fact=fact*i

    return fact
print(factorial(6))
# Out:
# 720

# %%
def count_even(lst): # to count even numbers 
    count=0

    for num in lst:
        if num%2==0:
            count+=1
    return count

print(count_even([43,5,6,235,6,2,5,8,9]))
# Out:
# 4

# %%
def count(lst): # to count odd numbers
    count=0

    for num in lst:
        if num%2!=0:
          count+=1
    return count
print(count([2,4,5,21,89,431,53]) )
# Out:
# 5

# %%
def counnt(lst): #to count odd numbers
    count=0

    for num in lst:
        if num%2==1:
           count+=1
    return count
print(counnt([45,56,23,432,676,4]))
# Out:
# 3

# %%
def max_min(num):
    return max(num),min(num)
print(max_min([87,654,535,32,1]))
# Out:
# (654, 1)

# %%
def count(lst):
    count=0

    for
