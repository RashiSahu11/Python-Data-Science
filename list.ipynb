# %% [markdown]
# LIST

# %%
mob_app=['pinterest','whatsapp','telegram','instagram','swiggy','savana']
print(mob_app)
# Out:
# ['pinterest', 'whatsapp', 'telegram', 'instagram', 'swiggy', 'savana']

# %% [markdown]
# INDEXING AND SLICING

# %%
print(mob_app[1])#pos indexing
print(mob_app[5])
# Out:
# whatsapp
# savana

# %%
print(mob_app[-2])#neg indexing
print(mob_app[-5])
# Out:
# swiggy
# whatsapp

# %%
#slicing
print(mob_app[1:5])#start,end
print(mob_app[1:5:1])#start:end:gap
print(mob_app[:5])#if start not given
print(mob_app[3:])#if end of lst not given
print(mob_app[:])#for whole list
# Out:
# ['whatsapp', 'telegram', 'instagram', 'swiggy']
# ['whatsapp', 'telegram', 'instagram', 'swiggy']
# ['pinterest', 'whatsapp', 'telegram', 'instagram', 'swiggy']
# ['instagram', 'swiggy', 'savana']
# ['pinterest', 'whatsapp', 'telegram', 'instagram', 'swiggy', 'savana']

# %% [markdown]
# LIST METHODS

# %% [markdown]
# - append -  adds an element at the end of the list
# - insert - adds an element at any specific position
# - pop - delets an element from the end and also using index value
# - remove - deletes an element using the name of it
# - copy - make a copy of the list
# - sort - sort the elements in specific order
# - extend - combine two list

# %%
mob_app.append('netflix')
print(mob_app)
# Out:
# ['pinterest', 'whatsapp', 'telegram', 'instagram', 'swiggy', 'savana', 'netflix']

# %%
mob_app.insert(2,'maps')
print(mob_app)
# Out:
# ['pinterest', 'whatsapp', 'maps', 'telegram', 'instagram', 'swiggy', 'savana', 'netflix']

# %%
mob_app.pop() #delete last element by default
print(mob_app)
# Out:
# ['pinterest', 'whatsapp', 'maps', 'telegram', 'instagram', 'swiggy', 'savana']

# %%
mob_app.pop(0)
print(mob_app)
# Out:
# ['whatsapp', 'maps', 'telegram', 'instagram', 'swiggy', 'savana']

# %%
mob_app.remove('maps')
print(mob_app)
# Out:
# ['whatsapp', 'telegram', 'instagram', 'swiggy', 'savana']

# %%
mob_app2=mob_app.copy()
print(mob_app2)
print(mob_app)
# Out:
# ['whatsapp', 'telegram', 'instagram', 'swiggy', 'savana']
# ['whatsapp', 'telegram', 'instagram', 'swiggy', 'savana']

# %%
mob_app2.clear() 
print(mob_app2)
# Out:
# []

# %%
print(mob_app)
# Out:
# ['whatsapp', 'telegram', 'instagram', 'swiggy', 'savana']

# %%
mob_app.sort()
print(mob_app)
# Out:
# ['instagram', 'savana', 'swiggy', 'telegram', 'whatsapp']

# %%
lst=[1,2,3,4,5,6]
mob_app.extend(lst)
print(mob_app)
# Out:
# ['instagram', 'savana', 'swiggy', 'telegram', 'whatsapp', 1, 2, 3, 4, 5, 6]

# %%
lst.extend(mob_app)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6, 'instagram', 'savana', 'swiggy', 'telegram', 'whatsapp', 1, 2, 3, 4, 5, 6]

# %%
#reverse a string
x='hello'
print(x[::-1])
# Out:
# olleh

# %%
numbers=[1,2,3,4,5]

# %%
numbers=[10,20,30]
numbers.append([40,50])
print(numbers)
# Out:
# [10, 20, 30, [40, 50]]

# %%
numbers=[10,20,30]
numbers.extend([40,50])
print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %%
lst=[4,6,2,78,43,6,8,90,5]# print only index value of 2
print(lst[::2])
# Out:
# [4, 2, 43, 8, 5]

# %%
l=("pynative")
print [:l%2==0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 l=("pynative")
# ----> 2 print [:l%2==0]
#       3
#
# TypeError: not all arguments converted during string formatting
